# %%
import pickle
import matplotlib.pyplot as plt
import os
import cv2

# %%
with open('brain_tumor','rb') as f:
    sv = pickle.load(f)

# %%
dec = {0:'No_Tumor', 1:'pituitary_tumor', 2:'meningioma_tumor'} # , 3:'glioma_tumor'

# %%
plt.figure(figsize=(12,8))
p = os.listdir('C:/Users/nitin/Documents/nlp/college project/Testing/')
c=1
for i in os.listdir('C:/Users/nitin/Documents/nlp/college project/Testing/meningioma_tumor/')[:16]:
    plt.subplot(4,4,c)
    
    img = cv2.imread('C:/Users/nitin/Documents/nlp/college project/Testing/meningioma_tumor/'+i,0)
    img1 = cv2.resize(img, (200,200))
    img1 = img1.reshape(1,-1)/255
    p = sv.predict(img1)
    plt.title(dec[p[0]])
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    c+=1

# %%
#plt.figure(figsize=(12,8))

img = cv2.imread('C:/Users/nitin/Documents/nlp/college project/m.jpg',0)
img1 = cv2.resize(img, (200,200))
img1 = img1.reshape(1,-1)/255
p = sv.predict(img1)
plt.title(dec[p[0]])
plt.imshow(img, cmap='gray')
plt.axis('off')
#plt.imshow(img, cmap='gray')
img
# Out:
# array([[28, 17, 14, ..., 15, 10, 16],
#        [13,  2,  0, ...,  0,  1,  7],
#        [13,  2,  0, ...,  0,  1,  7],
#        ...,
#        [14,  3,  0, ...,  0,  0,  9],
#        [13,  2,  0, ...,  0,  3,  3],
#        [13,  2,  0, ...,  0,  3,  3]], dtype=uint8)
